# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
data = "../../DataSets/DT/mushroom/agaricus-lepiota.data"
df = pd.read_csv(data, header= None)

# %%
df.columns = (['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat'])

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.size
# Out:
# 186852

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
df = df[~(df == '?').any(axis=1)]

# %%
x = df[['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']].values

# %%
x.shape
# Out:
# (5644, 22)

# %%
x[:3]
# Out:
# array([['x', 's', 'n', 't', 'p', 'f', 'c', 'n', 'k', 'e', 'e', 's', 's',
#         'w', 'w', 'p', 'w', 'o', 'p', 'k', 's', 'u'],
#        ['x', 's', 'y', 't', 'a', 'f', 'c', 'b', 'k', 'e', 'c', 's', 's',
#         'w', 'w', 'p', 'w', 'o', 'p', 'n', 'n', 'g'],
#        ['b', 's', 'w', 't', 'l', 'f', 'c', 'b', 'n', 'e', 'c', 's', 's',
#         'w', 'w', 'p', 'w', 'o', 'p', 'n', 'n', 'm']], dtype=object)

# %%
y = df['class']

# %%
y[:3]
# Out:
# C:\Users\Fatemeh\AppData\Local\Temp\ipykernel_13004\721213638.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   y[:3]
# 0    p
# 1    e
# 2    e
# Name: class, dtype: object

# %%
lab_capshape = preprocessing.LabelEncoder()
lab_capshape.fit(['b', 'c', 'x', 'f', 'k', 's'])
x[:,0] = lab_capshape.transform(x[:,0])

# %%
lab_capsurface = preprocessing.LabelEncoder()
lab_capsurface.fit(['f', 'g', 'y', 's'])
x[:,1] = lab_capsurface.transform(x[:,1])

# %%
lab_capcolor = preprocessing.LabelEncoder()
lab_capcolor.fit(['n', 'b', 'c', 'g', 'r', 'p', 'u', 'e', 'w', 'y'])
x[:,2] = lab_capcolor.transform(x[:,2])

# %%
lab_bruises = preprocessing.LabelEncoder()
lab_bruises.fit(['t', 'f'])
x[:,3] = lab_bruises.transform(x[:,3])

# %%
lab_odor = preprocessing.LabelEncoder()
lab_odor.fit(['a', 'l', 'c', 'y', 'f', 'm', 'n', 'p', 's'])
x[:,4] = lab_odor.transform(x[:,4])

# %%
lab_gillattachment = preprocessing.LabelEncoder()
lab_gillattachment.fit(['a', 'd', 'f', 'n'])
x[:,5] = lab_gillattachment.transform(x[:,5])

# %%
lab_gillspacing = preprocessing.LabelEncoder()
lab_gillspacing.fit(['c', 'w', 'd'])
x[:,6] = lab_gillspacing.transform(x[:,6])

# %%
lab_gillsize = preprocessing.LabelEncoder()
lab_gillsize.fit(['b', 'n'])
x[:,7] = lab_gillsize.transform(x[:,7])

# %%
lab_gillcolor = preprocessing.LabelEncoder()
lab_gillcolor.fit(['k', 'n', 'b', 'h', 'g', 'r', 'o', 'p', 'u', 'e', 'w', 'y'])
x[:,8] = lab_gillcolor.transform(x[:,8])

# %%
lab_stalkshape = preprocessing.LabelEncoder()
lab_stalkshape.fit(['e', 't'])
x[:,9] = lab_stalkshape.transform(x[:,9])

# %%
lab_stalkroot = preprocessing.LabelEncoder()
lab_stalkroot.fit(['b', 'c', 'u', 'e', 'z', 'r'])
x[:,10] = lab_stalkroot.transform(x[:,10])

# %%
lab_stalkSurfaceAboveRing = preprocessing.LabelEncoder()
lab_stalkSurfaceAboveRing.fit(['f', 'y', 'k', 's'])
x[:,11] = lab_stalkSurfaceAboveRing.transform(x[:,11])

# %%
lab_stalkSurfaceBelowRing = preprocessing.LabelEncoder()
lab_stalkSurfaceBelowRing.fit(['f', 'y', 'k', 's'])
x[:,12] = lab_stalkSurfaceBelowRing.transform(x[:,12])

# %%
lab_stalkColorAboveRing = preprocessing.LabelEncoder()
lab_stalkColorAboveRing.fit(['n', 'b', 'c', 'g', 'o', 'p', 'e', 'w', 'y'])
x[:,13] = lab_stalkColorAboveRing.transform(x[:,13])

# %%
lab_stalkColorBelowRing = preprocessing.LabelEncoder()
lab_stalkColorBelowRing.fit(['n', 'b', 'c', 'g', 'o', 'p', 'e', 'w', 'y'])
x[:,14] = lab_stalkColorBelowRing.transform(x[:,14])

# %%
lab_veilType = preprocessing.LabelEncoder()
lab_veilType.fit(['p', 'u'])
x[:,15] = lab_veilType.transform(x[:,15])

# %%
lab_veilColor = preprocessing.LabelEncoder()
lab_veilColor.fit(['n', 'o', 'w', 'y'])
x[:,16] = lab_veilColor.transform(x[:,16])

# %%
lab_ringNumber = preprocessing.LabelEncoder()
lab_ringNumber.fit(['n', 'o', 't'])
x[:,17] = lab_ringNumber.transform(x[:,17])

# %%
lab_ringType = preprocessing.LabelEncoder()
lab_ringType.fit(['c', 'e', 'f', 'l', 'n', 'p', 's', 'z'])
x[:,18] = lab_ringType.transform(x[:,18])

# %%
lab_sporePrintColor = preprocessing.LabelEncoder()
lab_sporePrintColor.fit(['k', 'n', 'b', 'h', 'r', 'o', 'u', 'w', 'y'])
x[:,19] = lab_sporePrintColor.transform(x[:,19])

# %%
lab_population = preprocessing.LabelEncoder()
lab_population.fit(['a', 'c', 'n', 's', 'v', 'y'])
x[:,20] = lab_population.transform(x[:,20])

# %%
lab_habitat = preprocessing.LabelEncoder()
lab_habitat.fit(['g', 'l', 'm', 'p', 'u', 'w', 'd'])
x[:,21] = lab_habitat.transform(x[:,21])

# %%
x[:5]
# Out:
# array([[5, 2, 4, 1, 6, 2, 0, 1, 4, 0, 2, 2, 2, 7, 7, 0, 2, 1, 5, 2, 3, 5],
#        [5, 2, 9, 1, 0, 2, 0, 0, 4, 0, 1, 2, 2, 7, 7, 0, 2, 1, 5, 3, 2, 1],
#        [0, 2, 8, 1, 3, 2, 0, 0, 5, 0, 1, 2, 2, 7, 7, 0, 2, 1, 5, 3, 2, 3],
#        [5, 3, 8, 1, 6, 2, 0, 1, 5, 0, 2, 2, 2, 7, 7, 0, 2, 1, 5, 2, 3, 5],
#        [5, 2, 3, 0, 5, 2, 2, 0, 4, 1, 2, 2, 2, 7, 7, 0, 2, 1, 1, 3, 0, 1]],
#       dtype=object)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 3)

# %%
mushroom_DT = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4)

# %%
mushroom_DT.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
y_predicted = mushroom_DT.predict(x_test)

# %%
print(metrics.accuracy_score(y_test, y_predicted))
# Out:
# 0.9899645808736718

# %%
from io import StringIO
import pydotplus
from sklearn import tree
import matplotlib.image as mpimg

# %%
dotData = StringIO()
fileName = "mushroomTree.png"
featureName = df.columns[:22]
out = tree.export_graphviz(mushroom_DT, feature_names = featureName, out_file = dotData, class_names = np.unique(y_train), filled = True, special_characters = True, rotate = False)
graph = pydotplus.graph_from_dot_data(dotData.getvalue())
graph.write_png(fileName)
img = mpimg.imread(fileName)
plt.figure(figsize=(100, 200))
plt.imshow(img,interpolation='nearest')
